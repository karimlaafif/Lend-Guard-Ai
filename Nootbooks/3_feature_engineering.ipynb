# %%
import pandas as pd
from src.data_prep import load_data, clean_data
from src.feature_eng import add_features

df = pd.read_csv("Datasets\Loan_default.csv")
df = clean_data(df)
df = add_features(df)

display(df.head())

# Vérifie la création des nouvelles features
print("Features après feature engineering", df.columns.tolist())
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\L'
# <>:5: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\PC\AppData\Local\Temp\ipykernel_32764\2636915621.py:5: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_csv("Datasets\Loan_default.csv")
# C:\Users\PC\AppData\Local\Temp\ipykernel_32764\2636915621.py:5: SyntaxWarning: invalid escape sequence '\L'
#   df = pd.read_csv("Datasets\Loan_default.csv")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from src.data_prep import load_data, clean_data
#       3 from src.feature_eng import add_features
#       5 df = pd.read_csv("Datasets\Loan_default.csv")
#
# ModuleNotFoundError: No module named 'src'
