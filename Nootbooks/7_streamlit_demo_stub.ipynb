# %%
import requests
import pandas as pd

payload = {
    "amount": 1000,
    "income": 5000,
    # Exemples: ajoute les features attendues par tes endpoints API
}

# Pour le scoring crédit
response = requests.post("http://localhost:8000/risk", json=payload)
print("Score de risque :", response.json())

# Pour la fraude
response = requests.post("http://localhost:8000/fraud", json=payload)
print("Anomalie/suspicion de fraude :", response.json())
